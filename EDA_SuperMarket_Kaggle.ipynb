# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Get Data

# %%
df = pd.read_csv('supermarket.csv')

# %%
df.shape
# Out:
# (9800, 18)

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11  Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City     State  Postal Code  \
# 0   Claire Gute  Consumer  United States  Henderson  Kentucky      42420.0
# 1   Claire Gute  Consumer  United States  Henderson  Kentucky      42420.0
#
#   Region       Product ID   Category Sub-Category  \
# 0  South  FUR-BO-10001798  Furniture    Bookcases
# 1  South  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94

# %% [markdown]
#  voici une explication de ce que chaque colonne représente  :
#
# 1. **Row ID**: Identifiant unique de chaque ligne du dataframe.
#
# 2. **Order ID**: Identifiant unique de chaque commande passée par un client.
#
# 3. **Order Date**: La date à laquelle la commande a été passée.
#
# 4. **Ship Date**: La date à laquelle la commande a été expédiée.
#
# 5. **Ship Mode**: Le mode d'expédition de la commande (par exemple, standard, express, etc.).
#
# 6. **Customer ID**: Identifiant unique du client qui a passé la commande.
#
# 7. **Customer Name**: Le nom du client.
#
# 8. **Segment**: Le segment de marché auquel le client appartient (par exemple, entreprise, consommateur, etc.).
#
# 9. **Country**: Le pays où la commande a été passée.
#
# 10. **City**: La ville où la commande a été passée.
#
# 11. **State**: L'état ou la province où la commande a été passée.
#
# 12. **Postal Code**: Le code postal associé à l'adresse de livraison.
#
# 13. **Region**: La région géographique où la commande a été passée.
#
# 14. **Product ID**: Identifiant unique du produit commandé.
#
# 15. **Category**: La catégorie générale à laquelle appartient le produit (par exemple, électronique, meubles, etc.).
#
# 16. **Sub-Category**: La sous-catégorie spécifique à laquelle appartient le produit (par exemple, téléviseurs, chaises, etc.).
#
# 17. **Product Name**: Le nom du produit commandé.
#
# 18. **Sales**: Le montant destes, les préférences des clients, etc.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
100*df.isnull().sum()/df.shape[0]
df = df.fillna(method='ffill')
100*df.isnull().sum()/df.shape[0]
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_1412\570954891.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')
# Row ID           0.0
# Order ID         0.0
# Order Date       0.0
# Ship Date        0.0
# Ship Mode        0.0
# Customer ID      0.0
# Customer Name    0.0
# Segment          0.0
# Country          0.0
# City             0.0
# State            0.0
# Postal Code      0.0
# Region           0.0
# Product ID       0.0
# Category         0.0
# Sub-Category     0.0
# Product Name     0.0
# Sales            0.0
# dtype: float64

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], errors='coerce')

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11  Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City     State  Postal Code  \
# 0   Claire Gute  Consumer  United States  Henderson  Kentucky      42420.0
# 1   Claire Gute  Consumer  United States  Henderson  Kentucky      42420.0
#
#   Region       Product ID   Category Sub-Category  \
# 0  South  FUR-BO-10001798  Furniture    Bookcases
# 1  South  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     3959 non-null   datetime64[ns]
#  3   Ship Date      3815 non-null   datetime64[ns]
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9800 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# L'analyse univariée en EDA (Exploratory Data Analysis) consiste à examiner les caractéristiques d'une variable individuellement, sans considérer leur relation avec d'autres variables. L'objectif principal est de comprendre la distribution et les caractéristiques d'une seule variable à la fois.
#
# Voici les grandes étapes pour réaliser une analyse univariée sur un dataset :
#
# 1. **Comprendre les types de variables** : Identifiez le type de données de chaque variable (numérique, catégorielle, temporelle, etc.). Cela déterminera les méthodes d'analyse appropriées.
#
# 2. **Statistiques descriptives** : Calculez des statistiques descriptives telles que la moyenne, la médiane, l'écart type, le minimum, le maximum, etc., pour les variables numériques. Pour les variables catégorielles, vous pouvez compter les occurrences de chaque catégorie.
#
# 3. **Visualisation des distributions** : Utilisez des histogrammes pour représenter graphiquement la distribution des variables numériques. Pour les variables catégorielles, vous pouvez utiliser des diagrammes à barres pour afficher la fréquence de chaque catégorie.
#
# 4. **Analyse des valeurs manquantes** : Identifiez les valeurs manquantes dans les données et évaluez leur impact potentiel sur l'analyse.
#
# 5. **Gestion des valeurs aberrantes** : Identifiez et évaluez les valeurs aberrantes (outliers) dans les variables numériques. Déterminez s'il est nécessaire de les traiter ou de les laisser en fonction du contexte de l'analyse.
#
# 6. **Analyse de la distribution** : Examinez la distribution des variables numériques pour déterminer si elles suivent une distribution normale ou une autre distribution spécifique. Vous pouvez utiliser des tests statistiques ou des visualisations comme les qq-plots pour cela.
#
# 7. **Analyse de la tendance centrale et de la dispersion** : Explorez la tendance centrale (moyenne, médiane, mode) et la dispersion (écart type, plage interquartile) des variables numériques pour comprendre leur comportement global.
#
# 8. **Analyse des valeurs catégorielles** : Pour les variables catégorielles, examinez la répartition des catégories et identifiez les catégories dominantes ouentes.
#
# En résumé, l'analyse univariée permet d'obtenir un aperçu approfondi des caractéristiques individuelles du dataset, ce qui est essentiel pour comprendre la structure des données et orienter les analyses plus avancées dans le processus d'exploration des données.équentes.

# %% [markdown]
# ## Categorical Data

# %% [markdown]
# ### CountPlot

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='Segment', data=df, label='Client')   #Categorical data concerning the Client we shipped to
sns.countplot(x='Ship Mode', data=df, label='order') # Categorical data concerning Order/Shipping
sns.countplot(x='Category', data=df, label='Product')  # Categorical data concerning the product Sipped
plt.xticks(rotation=75)
plt.title('Count Chart for client order and product')
plt.legend()

# %% [markdown]
# ### Pie Chart

# %%
categories = df['Category'].value_counts().index.tolist()
counts = df['Category'].value_counts().values.tolist()
colors = sns.color_palette('bright')[7:11] 

'''
We can replace pastel by :

deep
muted
bright
dark
colorblind
'''

plt.figure(figsize=(4,4))
plt.pie(counts, labels=categories, colors=colors, autopct='%1.1f%%', startangle=70)
plt.axis('equal')
plt.title('My Pie Chart')
# Out:
# Text(0.5, 1.0, 'My Pie Chart')

# %% [markdown]
# ## Numerical Data

# %% [markdown]
# ### Histogram

# %%
plt.figure(figsize=(4,4))
sns.histplot(x='Postal Code', data=df, kde=True, color='skyblue')
plt.title('Histogram with seaborn')
plt.xlabel('Values of Postal codes')
plt.ylabel('Frequencies')
plt.grid(axis='y', linestyle='--', alpha=0.7)
